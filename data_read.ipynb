# %%
import pandas as pd 
data = pd.read_csv('district-statistics.csv')
data
# Out:
#           ID  Total Pop  Devation     Dem     Rep      Oth  Total VAP   White  \
# Un       0.0     0.0000    0.6667  0.3333  0.0000      0.0     0.0000  0.0000
# 1    59444.0    -0.0015    0.4304  0.5516  0.0180  48427.0     0.9391  0.0609
# 2    59764.0     0.0039    0.4114  0.5633  0.0253  46407.0     0.9062  0.0938
# 3    59728.0     0.0033    0.4200  0.5580  0.0220  44826.0     0.8981  0.1019
# 4    59636.0     0.0017    0.4498  0.5267  0.0235  46594.0     0.8480  0.1520
# ..       ...        ...       ...     ...     ...      ...        ...     ...
# 96   59312.0    -0.0037    0.4702  0.5082  0.0217  44619.0     0.9417  0.0583
# 97   59664.0     0.0022    0.3624  0.6139  0.0236  46607.0     0.8508  0.1492
# 98   59406.0    -0.0021    0.3771  0.5995  0.0235  47330.0     0.8336  0.1664
# 99   59677.0     0.0024    0.2885  0.6932  0.0183  46349.0     0.9354  0.0646
# NaN      NaN        NaN       NaN     NaN     NaN      NaN        NaN     NaN
#
# ...
